# %%
import cv2
import subprocess

# %%
ruta_oxigenos_data = 'Results/Oxygen_reset_0.pkl'
ruta_configuracion_data = 'Results/Configurations_reset_0.pkl'

ruta_oxigenos_save = 'Videos/Oxygen.mp4'
ruta_configuracion_save = 'Videos/Configuracion.mp4'
ruta_simulation_save = 'Videos/Simulacion_sistema.mp4'

# %%
subprocess.run(["python", "Generar_videos.py", ruta_configuracion_data, ruta_configuracion_save])
# Out:
# CompletedProcess(args=['python', 'Generar_videos.py', 'Results/Configurations_reset_0.pkl', 'Videos/Configuracion.mp4'], returncode=1)

# %%
subprocess.run(["python", "ReprePal_configuracion.py", ruta_configuracion_data, ruta_configuracion_save])
subprocess.run(["python", "ReprePal_oxigeno.py", ruta_oxigenos_data, ruta_oxigenos_save])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 subprocess.run(["python", "ReprePal_configuracion.py", ruta_configuracion_data, ruta_configuracion_save])
#       2 subprocess.run(["python", "ReprePal_oxigeno.py", ruta_oxigenos_data, ruta_oxigenos_save])
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1588, in Popen._wait(self, timeout)
#    1585     timeout_millis = int(timeout * 1000)
#    1586 if self.returncode is None:
#    1587     # API note: Returns immediately if timeout_millis == 0.
# -> 1588     result = _winapi.WaitForSingleObject(self._handle,
#    1589                                          timeout_millis)
#    1590     if result == _winapi.WAIT_TIMEOUT:
#    1591         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
# Cargar los videos
video1 = cv2.VideoCapture(ruta_configuracion_save)
video2 = cv2.VideoCapture(ruta_oxigenos_save)

# Obtener el tamaño del video
frame_width = int(video1.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(video1.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(video1.get(cv2.CAP_PROP_FPS))

# Crear un objeto VideoWriter para guardar el video resultante
out = cv2.VideoWriter(ruta_simulation_save, cv2.VideoWriter_fourcc(*'mp4v'),
                      fps, (frame_width, frame_height))

while True:
    ret1, frame1 = video1.read()
    ret2, frame2 = video2.read()

    if not ret1 or not ret2:
        break

    # Normalizar los frames de ambos videos
    frame1 = cv2.normalize(frame1, None, 0, 255, cv2.NORM_MINMAX)
    frame2 = cv2.normalize(frame2, None, 0, 255, cv2.NORM_MINMAX)

    # Superponer los frames
    blended_frame = cv2.addWeighted(frame1, 0.5, frame2, 0.5, 0)

    # Escribir el frame resultante
    out.write(blended_frame)

# Liberar los objetos
video1.release()
video2.release()
out.release()
cv2.destroyAllWindows()
