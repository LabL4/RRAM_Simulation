# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Leer datos del fichero txt
data = np.loadtxt('datos.txt')

# Asumimos que los datos están en dos columnas: x e y
x = data[:, 0]
y = data[:, 1]

# Crear la gráfica scatter
plt.scatter(x, y)

# Configurar el eje y en escala logarítmica
plt.yscale('log')

# Añadir etiquetas y título
plt.xlabel('Eje X')
plt.ylabel('Eje Y (Escala Logarítmica)')
plt.title('Gráfica Scatter con Eje Y en Escala Logarítmica')

# Mostrar la gráfica
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Leer datos del fichero txt
# ----> 2 data = np.loadtxt('datos.txt')
#       4 # Asumimos que los datos están en dos columnas: x e y
#       5 x = data[:, 0]
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Ruta proporcionada
ruta = 'C:/Users/Usuario/Desktop/Datos_ciclos_RRAM/Ciclos_Set'

# Obtener lista de archivos en la ruta que no contienen 'n' en su nombre
archivos = [f for f in os.listdir(ruta) if os.path.isfile(os.path.join(ruta, f)) and 'n' not in f]

# Inicializar listas para almacenar datos
x_total = []
y_total = []

# Leer y procesar cada archivo
for archivo in archivos:
    data = np.loadtxt(os.path.join(ruta, archivo))
    x_total.extend(data[:, 0])
    y_total.extend(data[:, 1])

# Crear la gráfica scatter
plt.scatter(x_total, y_total)

# Configurar el eje y en escala logarítmica
plt.yscale('log')

# Añadir etiquetas y título
plt.xlabel('Voltaje [V]')
plt.ylabel('Intensidad [A]')
plt.title('Corriente de Set en función del Voltaje')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

# Solicitar la ruta del archivo al usuario
ruta_archivo = 'C:/Users/Usuario/Desktop/Datos_ciclos_RRAM/Ciclos_Set/Cycle_p_7.txt'

# Leer datos del archivo
data = np.loadtxt(ruta_archivo)

# Asumimos que los datos están en dos columnas: x e y
x = data[:, 0]
y = data[:, 1]

# Crear la gráfica scatter
plt.plot(x, y)

# Configurar el eje y en escala logarítmica
plt.yscale('log')

# Añadir etiquetas y título
plt.xlabel('Voltaje [V]')
plt.ylabel('Corriente [A]')
plt.title('Corriente en función del Voltaje')

# Mostrar la gráfica
plt.show()
