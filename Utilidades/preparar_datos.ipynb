# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import pickle

# ruta_raiz = 'C:/Users/Usuario/Documents/GitHub/RRAM_Simulation/'
ruta_raiz = '/Users/antonio_lopez_torres/Documents/GitHub/RRAM_Simulation/'  # Ruta en el mac
sys.path.append(ruta_raiz)

from RRAM import Representate as pplt

# %%
# Creo los vectores y luego los combino para generar los sets de datos a probar

I_0 = [1e-10, 5e-10, 1e-9, 5e-9, 1e-8, 5e-8, 1e-7, 5e-7]
ohm_resistence = [1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
gamma_drift = [7, 8, 9, 10, 11, 12]
gamma = [3, 4, 5, 6, 7, 8, 9, 10]

# %%
data = [(v1, v2, v3, v4) for v4 in gamma for v3 in gamma_drift for v2 in ohm_resistence for v1 in I_0]

print(data)
# Out:
# [(1e-10, 100000.0, 7, 3), (5e-10, 100000.0, 7, 3), (1e-09, 100000.0, 7, 3), (5e-09, 100000.0, 7, 3), (1e-08, 100000.0, 7, 3), (5e-08, 100000.0, 7, 3), (1e-07, 100000.0, 7, 3), (5e-07, 100000.0, 7, 3), (1e-10, 1000000.0, 7, 3), (5e-10, 1000000.0, 7, 3), (1e-09, 1000000.0, 7, 3), (5e-09, 1000000.0, 7, 3), (1e-08, 1000000.0, 7, 3), (5e-08, 1000000.0, 7, 3), (1e-07, 1000000.0, 7, 3), (5e-07, 1000000.0, 7, 3), (1e-10, 10000000.0, 7, 3), (5e-10, 10000000.0, 7, 3), (1e-09, 10000000.0, 7, 3), (5e-09, 10000000.0, 7, 3), (1e-08, 10000000.0, 7, 3), (5e-08, 10000000.0, 7, 3), (1e-07, 10000000.0, 7, 3), (5e-07, 10000000.0, 7, 3), (1e-10, 100000000.0, 7, 3), (5e-10, 100000000.0, 7, 3), (1e-09, 100000000.0, 7, 3), (5e-09, 100000000.0, 7, 3), (1e-08, 100000000.0, 7, 3), (5e-08, 100000000.0, 7, 3), (1e-07, 100000000.0, 7, 3), (5e-07, 100000000.0, 7, 3), (1e-10, 1000000000.0, 7, 3), (5e-10, 1000000000.0, 7, 3), (1e-09, 1000000000.0, 7, 3), (5e-09, 1000000000.0, 7, 3), (1e-08, 1000000000.0, 7, 3), (5e-
# ...

# %%
# Creo cada vector a partir de los datos, el primero es el I_0, el segundo la resistencia, el tercero el gamma_drift y el cuarto el gamma
I_0 = [v[0] for v in data]
ohm_resistence = [v[1] for v in data]
gamma_drift = [v[2] for v in data]
gamma = [v[3] for v in data]

print(I_0)
print(len(I_0))
# Out:
# [1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-07, 5e-07, 1e-10, 5e-10, 1e-09, 5e-09, 1e-08, 5e-08, 1e-
# ...
